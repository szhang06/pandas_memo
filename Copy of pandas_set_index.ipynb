# %%
people = {"first":["Corey", "Jane", "John"],
          "last": ["Schafer", "Doe", "Doe"],
          "email":["CoreyMSchafter@gamil.com", "JaneDoe@email.com", "JohnDoe@email.com"]}

# %%
import pandas as pd

# %%
people["email"]
# Out:
# ['CoreyMSchafter@gamil.com', 'JaneDoe@email.com', 'JohnDoe@email.com']

# %%
df = pd.DataFrame(people)

# %%
type(df.iloc[0])
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#    first     last                     email
# 0  Corey  Schafer  CoreyMSchafter@gamil.com
# 1   Jane      Doe         JaneDoe@email.com
# 2   John      Doe         JohnDoe@email.com

# %%
df[["email", "last"]]
# Out:
#                       email     last
# 0  CoreyMSchafter@gamil.com  Schafer
# 1         JaneDoe@email.com      Doe
# 2         JohnDoe@email.com      Doe

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
type(df[["email", "last"]])
# Out:
# pandas.core.frame.DataFrame

# %%
#按照index查找
# df.iloc[0] # index，所有括号里是index
# df.iloc[[0,1]] #包括1
df.iloc[[0,1], 2] #2 is third row; [0,1] is row 0 and 1
# Out:
# 0    CoreyMSchafter@gamil.com
# 1           JaneDoe@email.com
# Name: email, dtype: object

# %%
# use label, 0， 1,2....
df.loc[[0, 1], ['email', "last"]] # order according to str in the list
# df.loc[[0, 1], 2] # key error
# Out:
#                       email     last
# 0  CoreyMSchafter@gamil.com  Schafer
# 1         JaneDoe@email.com      Doe

# %%
df
# Out:
#    first     last                     email
# 0  Corey  Schafer  CoreyMSchafter@gamil.com
# 1   Jane      Doe         JaneDoe@email.com
# 2   John      Doe         JohnDoe@email.com

# %%
#set the index
# df.set_index("email") # (  ); # not change df
# df.set_index("email", inplace = True) # change df

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
# df.loc['CoreyMSchafter@gamil.com', "last"]
# df.loc[0] # error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-9fd61030dccd> in <module>()
# ----> 1 df.loc['CoreyMSchafter@gamil.com', "last"]
#       2 # df.loc[0] # error
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1042     def _getitem_tuple(self, tup: Tuple):
#    1043         try:
# -> 1044             return self._getitem_lowerdim(tup)
#    1045         except IndexingError:
#    1046             pass
#
# ...

# %%
df.iloc[0]
# Out:
# first                       Corey
# last                      Schafer
# email    CoreyMSchafter@gamil.com
# Name: 0, dtype: object

# %%
df
# Out:
#    first     last                     email
# 0  Corey  Schafer  CoreyMSchafter@gamil.com
# 1   Jane      Doe         JaneDoe@email.com
# 2   John      Doe         JohnDoe@email.com

# %%
# df.reset_index(inplace=True)
# df

# %%
filt = (df["last"] == "Doe")
filt
# Out:
# 0    False
# 1     True
# 2     True
# Name: last, dtype: bool

# %% [markdown]
# Filtering

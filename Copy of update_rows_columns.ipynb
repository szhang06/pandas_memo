# %%
people = {"first":["Corey", "Jane", "John"],
          "last": ["Schafer", "Doe", "Doe"],
          "email":["CoreyMSchafter@gamil.com", "JaneDoe@email.com", "JohnDoe@email.com"]}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)
df
# Out:
#    first     last                     email
# 0  Corey  Schafer  CoreyMSchafter@gamil.com
# 1   Jane      Doe         JaneDoe@email.com
# 2   John      Doe         JohnDoe@email.com

# %%
df.columns
# Out:
# Index(['first_name', 'last_name', 'email'], dtype='object')

# %%
df.columns = ["first_name", "last_name", "email"]
df
# Out:
#   first_name last_name                     email
# 0      Corey   Schafer  CoreyMSchafter@gamil.com
# 1       Jane       Doe         JaneDoe@email.com
# 2       John       Doe         JohnDoe@email.com

# %%
#df.columns = [x.upper()for x in df.columns] # change each column name#
#df
# Out:
#   FIRST_NAME LAST_NAME                     EMAIL
# 0      Corey   Schafer  CoreyMSchafter@gamil.com
# 1       Jane       Doe         JaneDoe@email.com
# 2       John       Doe         JohnDoe@email.com

# %%
#df.columns = df.columns.str.replace("_", " ")
#df
# Out:
#   FIRST NAME LAST NAME                     EMAIL
# 0      Corey   Schafer  CoreyMSchafter@gamil.com
# 1       Jane       Doe         JaneDoe@email.com
# 2       John       Doe         JohnDoe@email.com

# %%
df.rename(columns = {"first_name": "first", "last_name": "last"})
# Out:
#    first     last                     email
# 0  Corey  Schafer  CoreyMSchafter@gamil.com
# 1   Jane      Doe         JaneDoe@email.com
# 2   John      Doe         JohnDoe@email.com

# %%
df #original is still the same
# Out:
#   first_name last_name                     email
# 0      Corey   Schafer  CoreyMSchafter@gamil.com
# 1       Jane       Doe         JaneDoe@email.com
# 2       John       Doe         JohnDoe@email.com

# %%
df.rename(columns = {"first_name": "first", "last_name": "last"}, inplace=True) # change the original df
df
# Out:
#    first     last                     email
# 0  Corey  Schafer  CoreyMSchafter@gamil.com
# 1   Jane      Doe         JaneDoe@email.com
# 2   John      Doe         JohnDoe@email.com

# %%
#update rows and columns

df.loc[df["first"] == "John"] # choose first column == John ;  and df["last"] == "Doe" wrong
#df.loc[2] # only row
# Out:
#   first last              email
# 2  John  Doe  JohnDoe@email.com

# %%
#change last and email
#df.loc[2] = ["John", "Smith", "JohnSmith@email.com"] not for two manty values

#df.loc[2, ["last", "email"]] = ["Doe", "JohnDoe@email.com"]   # change two values
 df.loc[2, "last"] = "Smith" #change one value
# df.at[2, "last"] = "Doe" #same as above
df
# Out:
#    first     last                     email
# 0  Corey  Schafer  CoreyMSchafter@gamil.com
# 1   Jane      Doe         JaneDoe@email.com
# 2   John      Doe         JohnDoe@email.com

# %%
# error use
filt = (df["email"] =="JohnDoe@email.com")
#!  df[filt]["last"] = "Smith" # wrong
df.loc[filt, "last"] = "Smith"
df
# Out:
#    first     last                     email
# 0  Corey  Schafer  CoreyMSchafter@gamil.com
# 1   Jane      Doe         JaneDoe@email.com
# 2   John    Smith         JohnDoe@email.com

# %%
df["email"] = df["email"].str.lower() # change emails to lower cases
df
# Out:
#    first     last                     email
# 0  Corey  Schafer  coreymschafter@gamil.com
# 1   Jane      Doe         janedoe@email.com
# 2   John    Smith         johndoe@email.com

# %% [markdown]
# # change multiple rows
#
# apply //
# map //
# applymap//
# replace

# %%
df["email"].apply(len) #calculate email length
# Out:
# 0    24
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
def update_email(email):
  return email.upper()

# %%
df["email"] = df["email"].apply(update_email)
df
# Out:
#    first     last                     email
# 0  Corey  Schafer  COREYMSCHAFTER@GAMIL.COM
# 1   Jane      Doe         JANEDOE@EMAIL.COM
# 2   John    Smith         JOHNDOE@EMAIL.COM

# %%
df["email"] = df["email"].apply(lambda x: x.lower()) # only for Series
df
# Out:
#    first     last                     email
# 0  Corey  Schafer  coreymschafter@gamil.com
# 1   Jane      Doe         janedoe@email.com
# 2   John    Smith         johndoe@email.com

# %% [markdown]
# apply on DataFrame

# %%
df.apply(len, axis = "columns")
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
df.apply(pd.Series.min) # find the smallest in each column
# Out:
# first                       Corey
# last                          Doe
# email    coreymschafter@gamil.com
# dtype: object

# %% [markdown]
# apply on DataFrame

# %%
df.applymap(len) # apply to all values
# Out:
#    first  last  email
# 0      5     7     24
# 1      4     3     17
# 2      4     5     17

# %%
df.applymap(str.lower)
# Out:
#    first     last                     email
# 0  corey  schafer  coreymschafter@gamil.com
# 1   jane      doe         janedoe@email.com
# 2   john    smith         johndoe@email.com

# %%
# map for series
df["first"].map({"Corey": "Chris", "Jane": "May"}) # NaN
# Out:
# 0    Chris
# 1      May
# 2      NaN
# Name: first, dtype: object

# %%
df["first"] =df["first"].replace({"Corey": "Chris", "Jane": "May"}) # John remains
df
# Out:
#    first     last                     email
# 0  Chris  Schafer  coreymschafter@gamil.com
# 1    May      Doe         janedoe@email.com
# 2   John    Smith         johndoe@email.com

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/data/survey_results_public.csv", index_col="Respondent") #index_col= changes the index to Respondent
#df
pd.set_option("display.max_columns", 85) #显示最大数目column
pd.set_option("display.max_rows", 85)
schema_df = pd.read_csv("/content/drive/MyDrive/data/survey_results_schema.csv", index_col="Column")
#schema_df

# %%
df.rename(columns={"ConvertedComp": "SalaryUSD"}, inplace="True")

# %%
df["Hobbyist"] = df["Hobbyist"].map({"Yes": True, "No": False}) # no inplace value for map

# %%
df
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      True
# 2                      I am a student who is learning to code     False
# 3           I am not primarily a developer, but I write co...      True
# 4                              I am a developer by profession     False
# 5                              I am a developer by profession      True
# ...                                                       ...       ...
# 88377                                                     NaN      True
# 88601                                                     NaN     False
# 88802                                                     NaN     False
# 88816                                                     NaN     False
# 88863                                                     NaN      True
#
#                                                   OpenSourcer  \
# Respondent
# ...
